# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import matplotlib.pyplot as mp
import pandas as pd
import numpy as np
import h5py
import seaborn as sb
from sklearn.model_selection import train_test_split
#from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout, LeakyReLU
from tensorflow.keras.utils import to_categorical
from scipy.stats import zscore
from tensorflow.keras import optimizers

# %%
dataSet = h5py.File("SVHN_single_grey1.h5")
# Out:
# W:\AIML_Labs\Softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   """Entry point for launching an IPython kernel.

# %%
X_train = dataSet['X_train'][:]
X_test = dataSet['X_test'][:]
Y_train = dataSet['y_train'][:]
Y_test = dataSet['y_test'][:]

# %%
X_train.shape
# Out:
# (42000, 32, 32)

# %%
fig, axes = mp.subplots(4,4)
for i, ax in enumerate(axes.flat): 
    if X_train[i].shape == (32, 32):
        ax.imshow(X_train[i])
    else:
        ax.imshow(X_train[i,:,:,0])
    ax.set_xticks([]); ax.set_yticks([])
    ax.set_title(Y_train[i])

# %% [markdown]
# From the above display grid, we can observe that the images are of single channel - a negative image alike.

# %%
dataSet.close()

# %% [markdown]
# Plotting the Distribution to understand how the data is spread:

# %%
fig, (ax1, ax2) = mp.subplots(1, 2, sharex=True)

ax1.hist(Y_train, bins=10)
ax1.set_title("Training set")
ax1.set_xlim(1, 10)

ax2.hist(Y_test, color='g', bins=10)
ax2.set_title("Test set")

fig.tight_layout()

# %%
#Normalizing the above data by Subtracting the mean of training set from individual point.

# %%
X_train_mean = np.mean(X_train, axis = 0)
X_test_mean = np.mean(X_test, axis = 0)

# %%
X_train_std = np.std(X_train, axis = 0)
X_test_std = np.std(X_test, axis = 0)

# %%
X_train_normalized = (X_train-X_train_mean/X_train_std)
X_test_normalized = (X_test-X_test_mean/X_test_std)

# %% [markdown]
# Now splitting the X_train data into validation set and X_train values using train_test_split

# %%
train_X, Val_X, train_Y, Val_Y = train_test_split(X_train_normalized, Y_train, random_state =1, test_size = .1)

# %%
#Pre Processing the training X and Validate data that is to reduce the dimensions of the given data set from 3 to 2:
train_X = train_X.reshape((train_X.shape[0], -1))
test_X = X_test.reshape((X_test.shape[0], -1))
Val_X = Val_X.reshape((Val_X.shape[0],-1))

# %%
print (train_X.shape,test_X.shape,Val_X.shape)
# Out:
# (37800, 1024) (18000, 1024) (4200, 1024)

# %%
#Converting the classes to binary classification using the one hot encoding process.

# %%
train_Y = to_categorical(train_Y)
Y_test = to_categorical(Y_test)
Val_Y = to_categorical(Val_Y)

# %% [markdown]
# ### The dataset is now divided as Training set, Validation Set and Testing set.
# Building a Deep Neural Network model around the given dataset:---

# %%
model = Sequential()

# %%
#Creating a simple Feed forward model with activation function as signmoid.

# %%
# model.add(Dense(100, input_shape = (1024,), activation='sigmoid'))
# model.add(Dense(300,activation = 'sigmoid'))
# model.add(Dense(500,activation = 'sigmoid'))
# model.add(Dense(300,activation = 'sigmoid'))
# model.add(Dense(10, activation = 'softmax'))

# %%
  model.add(Dense(50, input_shape = (1024, )))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(10))
  model.add(Activation('softmax'))

sgd = optimizers.SGD(lr = 0.001)
model.compile(optimizer = sgd, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(train_X,train_Y, epochs = 100, batch_size = 100, verbose =1)
# Out:
# Train on 37800 samples
# Epoch 1/100
# 37800/37800 [==============================] - 2s 41us/sample - loss: 2.4220 - accuracy: 0.1000
# Epoch 2/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3509 - accuracy: 0.0999
# Epoch 3/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3223 - accuracy: 0.0990
# Epoch 4/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3102 - accuracy: 0.1010
# Epoch 5/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3053 - accuracy: 0.1010
# Epoch 6/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3035 - accuracy: 0.1009
# Epoch 7/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3029 - accuracy: 0.1009
# Epoch 8/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3027 - accuracy: 0.0989
# Epoch 9/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3026 - accuracy: 0.1003
# Epoch 10/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 11/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3026 - accuracy: 0.1011
# Epoch 12/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3026 - accuracy: 0.1011
# Epoch 13/100
# 37800/37800 [==============================] - 1s 31us/sample - loss: 2.3026 - accuracy: 0.1009
# Epoch 14/100
# 37800/37800 [==============================] - 1s 27us/sample - loss: 2.3026 - accuracy: 0.1004
# Epoch 15/100
# 37800/37800 [==============================] - 1s 28us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 16/100
# 37800/37800 [==============================] - 1s 29us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 17/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 18/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 19/100
# 37800/37800 [==============================] - 1s 27us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 20/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 21/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 22/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3026 - accuracy: 0.1018
# Epoch 23/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3025 - accuracy: 0.1017
# Epoch 24/100
# 37800/37800 [==============================] - 1s 30us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 25/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 26/100
# 37800/37800 [==============================] - 1s 27us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 27/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 28/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 29/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3025 - accuracy: 0.1008
# Epoch 30/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 31/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 32/100
# 37800/37800 [==============================] - 1s 31us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 33/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.0994
# Epoch 34/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1017
# Epoch 35/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 36/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 37/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1015
# Epoch 38/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 39/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 40/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 41/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 42/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 43/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 44/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 45/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1016
# Epoch 46/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 47/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 48/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 49/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1010
# Epoch 50/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 51/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3025 - accuracy: 0.1007
# Epoch 52/100
# 37800/37800 [==============================] - 1s 26us/sample - loss: 2.3025 - accuracy: 0.1012
# Epoch 53/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1010
# Epoch 54/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1015
# Epoch 55/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 56/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.0998
# Epoch 57/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 58/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 59/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 60/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 61/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1013
# Epoch 62/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 63/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1012
# Epoch 64/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 65/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 66/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.0995
# Epoch 67/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 68/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1003
# Epoch 69/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 70/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 71/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 72/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 73/100
# 37800/37800 [==============================] - 1s 25us/sample - loss: 2.3025 - accuracy: 0.1014
# Epoch 74/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 75/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1017
# Epoch 76/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1012
# Epoch 77/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 78/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 79/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 80/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1013
# Epoch 81/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1015
# Epoch 82/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 83/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.0993
# Epoch 84/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 85/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1039
# Epoch 86/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1012
# Epoch 87/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 88/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 89/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 90/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 91/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1017
# Epoch 92/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3025 - accuracy: 0.1018
# Epoch 93/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1004
# Epoch 94/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1018
# Epoch 95/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1018
# Epoch 96/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1018
# Epoch 97/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1018
# Epoch 98/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3024 - accuracy: 0.1001
# Epoch 99/100
# 37800/37800 [==============================] - 1s 23us/sample - loss: 2.3024 - accuracy: 0.1011
# Epoch 100/100
# 37800/37800 [==============================] - 1s 24us/sample - loss: 2.3024 - accuracy: 0.1018

# %%
#Evaluating the model on the validation dataSet
model.evaluate(Val_X,Val_Y)
# Out:
# 4200/4200 [==============================] - 0s 53us/sample - loss: 1.7269 - accuracy: 0.3686
# [1.7269392728805542, 0.36857143]

# %%
#Evaluating the model on actual test data
model.evaluate(test_X,Y_test)
# Out:
# 18000/18000 [==============================] - 1s 31us/sample - loss: 1.7174 - accuracy: 0.3766
# [1.7174113607406616, 0.37655556]

# %%
preds = model.predict_classes(test_X)

# %%
preds_val = model.predict_classes(Val_X)

# %%
preds_val
# Out:
# array([7, 6, 8, ..., 2, 1, 9], dtype=int64)

# %% [markdown]
# Thus, from above accuracy and loss metrices we can see that the model is poorly performing with accuracy of on 9% and a higher loss of 2.30. The observations are similar for both validation and the test data set.
