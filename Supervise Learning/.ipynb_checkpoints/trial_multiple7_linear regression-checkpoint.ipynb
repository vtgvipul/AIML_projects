# %%
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataSet = pd.read_csv("Trial_Multipler_Linear_regression.csv")

# %%
dataSet.shape
# Out:
# (600, 2)

# %%
dataSet
# Out:
#      Number  TimesSeven
# 0         1           7
# 1         2          14
# 2         3          21
# 3         4          28
# 4         5          35
# 5         6          42
# 6         7          49
# 7         8          56
# 8         9          63
# 9        10          70
# 10       11          77
# 11       12          84
# 12       13          91
# 13       14          98
# 14       15         105
# 15       16         112
# 16       17         119
# 17       18         126
# 18       19         133
# 19       20         140
# 20       21         147
# 21       22         154
# 22       23         161
# 23       24         168
# 24       25         175
# 25       26         182
# 26       27         189
# 27       28         196
# 28       29         203
# 29       30         210
# ..      ...         ...
# 570     571        3997
# 571     572        4004
# 572     573        4011
# 573     574        4018
# 574     575        4025
# 575     576        4032
# 576     577        4039
# 577     578        4046
# 578     579        4053
# 579     580        4060
# 580     581        4067
# 581     582        4074
# 582     583        4081
# 583     584        4088
# 584     585        4095
# 585     586        4102
# 586     587        4109
# 587     588        4116
# 588     589        4123
# 589     590        4130
# 590     591        4137
# 591     592        4144
# 592     593        4151
# 593     594        4158
# 594     595        4165
# 595     596        4172
# 596     597        4179
# 597     598        4186
# 598     599        4193
# 599     600        4200
#
# [600 rows x 2 columns]

# %%
dataSet.dtypes
# Out:
# Number        int64
# TimesSeven    int64
# dtype: object

# %%
x = dataSet[['Number']]
y = dataSet[['TimesSeven']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
linReg = LinearRegression()

# %%
linReg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_val = linReg.predict(x_test)

# %%
y_test.head()
# Out:
#      TimesSeven
# 586        4109
# 454        3185
# 35          252
# 297        2086
# 354        2485

# %%
pred_valdf = pd.DataFrame(data = pred_val)

# %%
pred_valdf.head()
# Out:
#         0
# 0  4109.0
# 1  3185.0
# 2   252.0
# 3  2086.0
# 4  2485.0

# %%
dataTab
# Out:
#                                            Predicted  \
# 0            0
# 0    4109.0
# 1    3185.0
# 2     252....
#
#                                               Actual
# 0       TimesSeven
# 586        4109
# 454        318...

# %%
sb.dogplot()
